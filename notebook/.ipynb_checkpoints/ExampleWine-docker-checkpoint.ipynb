# %% [markdown]
# # Setup use case Wine

# %%
from IPython.display import Image
from PIL import Image as pil_image
file_path = '1_Kae3ij4MK3mYDLvkblVlMA.webp'
pil_img = pil_image.open(file_path).convert('RGB')
tmp_path = 'temp.jpg'
pil_img.save(tmp_path, format='jpeg')
Image(filename=tmp_path)

# %% [markdown]
# ### Set up the auto completion

# %%
#install auto-completion 
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
from jedi import settings
settings.case_insensitive_completion = True
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 46.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython_genutils in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyter_core in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (4.12.0)
# Collecting jupyter_highlight_selected_word>=0.1.1
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter_nbextensions_configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.6.1.tar.gz (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.7/481.7 kB 38.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nbconvert>=6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (7.2.8)
# Requirement already satisfied: notebook>=6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.5.2)
# Requirement already satisfied: tornado in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: traitlets>=4.1 in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_nbextensions) (5.8.1)
# Collecting lxml
#   Downloading lxml-4.9.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 87.2 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (66.1.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.14.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: nbformat>=5.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.7.3)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.4.8)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (25.0.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.16.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbconvert>=6.0->jupyter_contrib_nbextensions) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.7/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.23.5)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.17.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.7/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.6)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.2)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.6)
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core, jupyter_nbextensions_configurator
#   Building wheel for jupyter_contrib_nbextensions (setup.py) ... done
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428784 sha256=2f5e694af8aebd9faae82a0f5b0f920ddf8072fb1f17ff86b947a70968efdb8c
#   Stored in directory: /home/jupyter/.cache/pip/wheels/76/10/93/75f07b7ce1559ae8eeba500906f821d6b6936548e27a439d59
#   Building wheel for jupyter_contrib_core (setup.py) ... done
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17483 sha256=bfd7de8dec14c24fe519ae6c3a48857482aa952714ca09dc8303286a5b5a7660
#   Stored in directory: /home/jupyter/.cache/pip/wheels/e4/15/2d/d9d6305e68b971a1378c232f9d888eefaebb11ddeb579fb8bb
#   Building wheel for jupyter_nbextensions_configurator (setup.py) ... done
#   Created wheel for jupyter_nbextensions_configurator: filename=jupyter_nbextensions_configurator-0.6.1-py2.py3-none-any.whl size=466845 sha256=458192b1f98795670e2eac8f6d77935a23b7b510b2faf3ea7754b57d119ee8c0
#   Stored in directory: /home/jupyter/.cache/pip/wheels/66/8d/99/311d8c5e33102d1c1f875ea0a67dbac5c0e56ad45b64467af4
# Successfully built jupyter_contrib_nbextensions jupyter_contrib_core jupyter_nbextensions_configurator
# Installing collected packages: jupyter_highlight_selected_word, lxml, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
# Successfully installed jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.1 lxml-4.9.2
# [I 18:03:16 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 18:03:16 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2 -> exercise2
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/exercise2/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/main.css -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/main.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/image.gif -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/image.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2/exercise2.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/exercise2/exercise2.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/nbTranslate.js -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/nbTranslate.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/languages.js -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/languages.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/demo2.gif -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/demo2.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/demo1.gif -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/demo1.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/README.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/mutils.js -> /home/jupyter/.local/share/jupyter/nbextensions/nbTranslate/mutils.js
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell -> init_cell
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/init_cell/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell/init_cell.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/init_cell/init_cell.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/init_cell/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/init_cell/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell/cell_toolbar_menu.png -> /home/jupyter/.local/share/jupyter/nbextensions/init_cell/cell_toolbar_menu.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/init_cell/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/init_cell/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter -> highlighter
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/highlighter/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.html -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/tst_highlights.html
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/export_highlights.pdf -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/export_highlights.pdf
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.ipynb -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/tst_highlights.ipynb
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/demo_highlighter.html -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/demo_highlighter.html
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/highlighter.css -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/highlighter.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/export_highlights.html -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/export_highlights.html
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/demo_highlighter.ipynb -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/demo_highlighter.ipynb
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.tex -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/tst_highlights.tex
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/highlighter.js -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/highlighter.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/image.gif -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/image.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/highlighter.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/highlighter.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.pdf -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/tst_highlights.pdf
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/export_highlights.tex -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/export_highlights.tex
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/export_highlights.ipynb -> /home/jupyter/.local/share/jupyter/nbextensions/highlighter/export_highlights.ipynb
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel -> help_panel
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/help_panel/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/help_panel.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/help_panel.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/help_panel.css -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/help_panel.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/help_panel_ext.png -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/help_panel_ext.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/help_panel_ext_fullscreen.png -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/help_panel_ext_fullscreen.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/help_panel.js -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/help_panel.js
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/help_panel/img
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel/img/handle-v.png -> /home/jupyter/.local/share/jupyter/nbextensions/help_panel/img/handle-v.png
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies/execution_dependencies.yml -> /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies/execution_dependencies.js -> /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/execution_dependencies/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering -> equation-numbering
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering/info.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/info.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering/button.png -> /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/button.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/equation-numbering/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/freeze/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/freeze/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/freeze/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze/config.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/freeze/config.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/freeze/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/hide_input/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/hide_input/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/hide_input/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/hide_input/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input/hide-input.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/hide_input/hide-input.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/screenshot.png -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/main.css -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/main.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/collapsible_headings.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell -> go_to_current_running_cell
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/jump_to_cell.gif -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/jump_to_cell.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/auto_focus.gif -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/auto_focus.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/eye.png -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/eye.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/go_to_current_running_cell.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/go_to_current_running_cell.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/anchor.png -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/anchor.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/go_to_current_running_cell/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor -> keyboard_shortcut_editor
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/main.css -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_comma.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_comma.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/kse_components.js -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/kse_components.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_conflict.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_conflict.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_dropdown.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_dropdown.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/README.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_menu_item.png -> /home/jupyter/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_menu_item.png
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/splitcell/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell/splitcell.js -> /home/jupyter/.local/share/jupyter/nbextensions/splitcell/splitcell.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/splitcell/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/splitcell/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell/splitcell.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/splitcell/splitcell.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/skill/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill/skill.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/skill/skill.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/skill/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill/skill.js -> /home/jupyter/.local/share/jupyter/nbextensions/skill/skill.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/skill/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise -> exercise
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/exercise/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/history.md -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/history.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/main.css -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/main.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/exercise.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/exercise.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise/image.gif -> /home/jupyter/.local/share/jupyter/nbextensions/exercise/image.gif
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time -> execute_time
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/execute_time/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/ExecuteTime.js -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/ExecuteTime.css -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/execution-timings-menu.png -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/execution-timings-menu.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/ExecuteTime.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time/execution-timings-box.png -> /home/jupyter/.local/share/jupyter/nbextensions/execute_time/execution-timings-box.png
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/scratchpad.css -> /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/scratchpad.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/demo.gif -> /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/demo.gif
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/LICENSE -> /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/LICENSE
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad/scratchpad.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/scratchpad/scratchpad.yaml
# ...
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview/livemdpreview.yml -> /home/jupyter/.local/share/jupyter/nbextensions/livemdpreview/livemdpreview.yml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/blockcomment-fold.js -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/foldgutter.css -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_indent_folded_1.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/magic-fold.js -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/magic-unfolded.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/magic-folded.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_indent_unfolded.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/firstline-fold.js -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_indent_folded_2.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_firstline_folded.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_firstline_unfolded.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_editor.png -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/edit.js -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding/codefolding_editor.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 18:03:16 InstallContribNbextensionsApp] Up to date: /home/jupyter/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codemirror_mode_extensions -> codemirror_mode_extensions
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/codemirror_mode_extensions/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codemirror_mode_extensions/codemirror_mode_extensions.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/codemirror_mode_extensions/codemirror_mode_extensions.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/codemirror_mode_extensions/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/codemirror_mode_extensions/main.js
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/select_keymap.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/select_keymap.png -> /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/select_keymap.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/select_keymap/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size -> code_font_size
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size/code_font_size.js -> /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/code_font_size.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size/code_font_size.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/code_font_size.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/code_font_size/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper -> datestamper
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/datestamper/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/datestamper/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/datestamper/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/datestamper/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper/main.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/datestamper/main.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded -> export_embedded
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded/readme.md -> /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/readme.md
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded/icon.png -> /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/icon.png
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded/export_embedded.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/export_embedded/export_embedded.yaml
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 18:03:16 InstallContribNbextensionsApp] Making directory: /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word/main.js -> /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/main.js
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word/configurator.yaml -> /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 18:03:16 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word/README.md -> /home/jupyter/.local/share/jupyter/nbextensions/highlight_selected_word/README.md
# [I 18:03:16 InstallContribNbextensionsApp] - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /home/jupyter/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/jupyter/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.6.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 18:03:16 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 18:03:16 InstallContribNbextensionsApp]       - Validating: OK
# [I 18:03:16 InstallContribNbextensionsApp] - Editing config: /home/jupyter/.jupyter/jupyter_nbconvert_config.json
# [I 18:03:16 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 18:03:16 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 18:03:16 InstallContribNbextensionsApp] - Writing config: /home/jupyter/.jupyter/jupyter_nbconvert_config.json
# [I 18:03:16 InstallContribNbextensionsApp] --  Writing updated config file /home/jupyter/.jupyter/jupyter_nbconvert_config.json

# %% [markdown]
# ### Set up the environment
# - Python 3
# - virtualenv
# - Jupyter notebook running in a virtual environment with Python 3
# - Docker
# - Git
# - Google Cloud SDK (gcloud)

# %% [markdown]
# ### Enable  the APIs if they are not enabled

# %%
# !gcloud services enable compute.googleapis.com         \
                       containerregistry.googleapis.com  \
                       aiplatform.googleapis.com  \
                       cloudbuild.googleapis.com \
                       cloudfunctions.googleapis.com
# Out:
# Operation "operations/acf.p2-196303161359-1baa985b-7405-45b8-9671-f1ffef3113f1" finished successfully.

# %% [markdown]
# ## Uncomment all needed cells if you need to install missing packages

# %%
# Install ai platform and kfp
USER_FLAG = "--user"
# !pip3 install {USER_FLAG} google-cloud-aiplatform==1.3.0 --upgrade
# !pip3 install {USER_FLAG} kfp --upgrade
# Out:
# Collecting google-cloud-aiplatform==1.3.0
#   Downloading google_cloud_aiplatform-1.3.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (1.34.0)
# Collecting google-cloud-storage<2.0.0dev,>=1.32.0
#   Downloading google_cloud_storage-1.44.0-py2.py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 15.2 MB/s eta 0:00:00
# Collecting google-cloud-bigquery<3.0.0dev,>=1.15.0
#   Downloading google_cloud_bigquery-2.34.4-py2.py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.6/206.6 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus>=1.10.1 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (1.22.2)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform==1.3.0) (23.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.28.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (3.19.6)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.48.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.51.1)
# Collecting packaging>=14.3
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.4.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (2.8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<2.0.0dev,>=1.32.0->google-cloud-aiplatform==1.3.0) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging>=14.3->google-cloud-aiplatform==1.3.0) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform==1.3.0) (1.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-aiplatform==1.3.0) (0.4.8)
# Installing collected packages: packaging, google-cloud-storage, google-cloud-bigquery, google-cloud-aiplatform
#   WARNING: The script tb-gcp-uploader is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed google-cloud-aiplatform-1.3.0 google-cloud-bigquery-2.34.4 google-cloud-storage-1.44.0 packaging-21.3
# Collecting kfp
#   Downloading kfp-1.8.19.tar.gz (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 8.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py<2,>=0.9 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.4.0)
# Collecting PyYAML<6,>=5.3
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.6/636.6 kB 13.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.34.0)
# Requirement already satisfied: google-cloud-storage<3,>=1.20.0 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp) (1.44.0)
# Collecting kubernetes<20,>=8.0.0
#   Downloading kubernetes-19.15.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (2.16.0)
# Collecting requests-toolbelt<1,>=0.8.0
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from kfp) (2.2.1)
# Collecting kfp-server-api<2.0.0,>=1.1.2
#   Downloading kfp-server-api-1.8.5.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonschema<5,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (4.17.3)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /opt/conda/lib/python3.7/site-packages (from kfp) (0.9.0)
# Requirement already satisfied: click<9,>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (8.1.3)
# Collecting Deprecated<2,>=1.2.7
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting strip-hints<1,>=0.1.8
#   Downloading strip-hints-0.1.10.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docstring-parser<1,>=0.7.3
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Collecting kfp-pipeline-spec<0.2.0,>=0.1.16
#   Downloading kfp_pipeline_spec-0.1.16-py3-none-any.whl (19 kB)
# Collecting fire<1,>=0.3.1
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf<4,>=3.13.0 in /opt/conda/lib/python3.7/site-packages (from kfp) (3.19.6)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp) (3.0.1)
# Requirement already satisfied: pydantic<2,>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (1.10.4)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /opt/conda/lib/python3.7/site-packages (from kfp) (0.7.0)
# Requirement already satisfied: typing-extensions<5,>=3.7.4 in /opt/conda/lib/python3.7/site-packages (from kfp) (4.4.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click<9,>=7.1.2->kfp) (6.0.0)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from fire<1,>=0.3.1->kfp) (1.16.0)
# Collecting termcolor
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (2.28.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (1.58.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.21.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3,>=1.6.1->kfp) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=1.20.0->kfp) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=1.20.0->kfp) (2.4.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp) (5.10.2)
# Requirement already satisfied: urllib3>=1.15 in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (1.26.14)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2022.12.7)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (66.1.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (1.4.2)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp) (1.3.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from strip-hints<1,>=0.1.8->kfp) (0.38.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage<3,>=1.20.0->kfp) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.7/site-packages (from httplib2<1dev,>=0.9.2->google-api-python-client<2,>=1.7.8->kfp) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema<5,>=3.0.1->kfp) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.1->kfp) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib->kubernetes<20,>=8.0.0->kfp) (3.2.2)
# Building wheels for collected packages: kfp, fire, kfp-server-api, strip-hints
#   Building wheel for kfp (setup.py) ... done
#   Created wheel for kfp: filename=kfp-1.8.19-py3-none-any.whl size=426959 sha256=74ab98696a7e420045c7e76b1c4c401278f2958a4c41a3f92477de61beb6ebbe
#   Stored in directory: /home/jupyter/.cache/pip/wheels/13/37/67/a4d6db71bf84e17d09b9ce85bbb08cb8a02dec2fabf9824c98
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116931 sha256=463c22da2c67913e8cf1376ff73f09c9553a919da814f3e535de1aee13541764
#   Stored in directory: /home/jupyter/.cache/pip/wheels/20/e8/7b/003fc14f02f262dd4614aec55e41147c8012e3dad98c936b76
#   Building wheel for kfp-server-api (setup.py) ... done
#   Created wheel for kfp-server-api: filename=kfp_server_api-1.8.5-py3-none-any.whl size=99699 sha256=28a961c0a4d0377f8673fcebaf89bf1a68de528210b65e7fdd56317241f5c676
#   Stored in directory: /home/jupyter/.cache/pip/wheels/64/f0/9d/dcf844b38d247b944657d0b9e8d55b76baef9bfdeb680e4596
#   Building wheel for strip-hints (setup.py) ... done
#   Created wheel for strip-hints: filename=strip_hints-0.1.10-py2.py3-none-any.whl size=22283 sha256=0a890170fb365cc197542802ca3e9fbbdd5b107373e3703d96bf2ba34ff4aff8
#   Stored in directory: /home/jupyter/.cache/pip/wheels/5a/4e/89/a4493443c6aadb8a38e9709610efc3bfafaea3a4108df4c112
# Successfully built kfp fire kfp-server-api strip-hints
# Installing collected packages: wrapt, termcolor, strip-hints, PyYAML, kfp-pipeline-spec, docstring-parser, requests-toolbelt, kfp-server-api, fire, Deprecated, kubernetes, kfp
#   WARNING: The script strip-hints is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dsl-compile, dsl-compile-v2 and kfp are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Deprecated-1.2.13 PyYAML-5.4.1 docstring-parser-0.15 fire-0.5.0 kfp-1.8.19 kfp-pipeline-spec-0.1.16 kfp-server-api-1.8.5 kubernetes-19.15.0 requests-toolbelt-0.10.1 strip-hints-0.1.10 termcolor-2.2.0 wrapt-1.15.0

# %%
# !pip install google_cloud_pipeline_components
# Out:
# Collecting google_cloud_pipeline_components
#   Downloading google_cloud_pipeline_components-1.0.39-py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.6/870.6 kB 16.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: kfp<2.0.0,>=1.8.9 in /home/jupyter/.local/lib/python3.7/site-packages (from google_cloud_pipeline_components) (1.8.19)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.7/site-packages (from google_cloud_pipeline_components) (1.58.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5 in /opt/conda/lib/python3.7/site-packages (from google_cloud_pipeline_components) (1.34.0)
# Collecting google-cloud-aiplatform<2,>=1.14.0
#   Downloading google_cloud_aiplatform-1.22.1-py2.py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.7 MB/s eta 0:00:00:00:01
# Collecting google-cloud-notebooks>=0.4.0
#   Downloading google_cloud_notebooks-1.6.1-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.1/190.1 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4.0.0dev,>=3.19.0 in /opt/conda/lib/python3.7/site-packages (from google_cloud_pipeline_components) (3.19.6)
# Collecting google-cloud-storage<3,>=2.2.1
#   Downloading google_cloud_storage-2.7.0-py2.py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.2/110.2 kB 12.9 MB/s eta 0:00:00
# Collecting grpcio-status<=1.47.0
#   Downloading grpcio_status-1.47.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (2.16.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (2.28.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (1.8.1)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /home/jupyter/.local/lib/python3.7/site-packages (from google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (2.34.4)
# Requirement already satisfied: shapely<2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (1.8.5.post1)
# Requirement already satisfied: packaging<22.0.0dev,>=14.3 in /home/jupyter/.local/lib/python3.7/site-packages (from google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (21.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (1.22.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.7/site-packages (from google-cloud-notebooks>=0.4.0->google_cloud_pipeline_components) (0.12.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=2.2.1->google_cloud_pipeline_components) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-storage<3,>=2.2.1->google_cloud_pipeline_components) (2.4.1)
# Requirement already satisfied: grpcio>=1.47.0 in /opt/conda/lib/python3.7/site-packages (from grpcio-status<=1.47.0->google_cloud_pipeline_components) (1.51.1)
# Requirement already satisfied: typing-extensions<5,>=3.7.4 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (4.4.0)
# Requirement already satisfied: PyYAML<6,>=5.3 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (5.4.1)
# Requirement already satisfied: jsonschema<5,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (4.17.3)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.9.0)
# Requirement already satisfied: absl-py<2,>=0.9 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.4.0)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.8.5)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.7.0)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.16 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.1.16)
# Requirement already satisfied: click<9,>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (8.1.3)
# Requirement already satisfied: fire<1,>=0.3.1 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.5.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.8.0)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (2.2.1)
# Requirement already satisfied: Deprecated<2,>=1.2.7 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.2.13)
# Requirement already satisfied: pydantic<2,>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.10.4)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.1.10)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.10.1)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.15)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (3.0.1)
# Requirement already satisfied: kubernetes<20,>=8.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (19.15.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click<9,>=7.1.2->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (6.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/jupyter/.local/lib/python3.7/site-packages (from Deprecated<2,>=1.2.7->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.15.0)
# Requirement already satisfied: termcolor in /home/jupyter/.local/lib/python3.7/site-packages (from fire<1,>=0.3.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (2.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from fire<1,>=0.3.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.16.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.8->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.21.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (0.2.8)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (2.8.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3,>=2.2.1->google_cloud_pipeline_components) (1.5.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (5.10.2)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema<5,>=3.0.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.3.10)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (2022.12.7)
# Requirement already satisfied: urllib3>=1.15 in /opt/conda/lib/python3.7/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.26.14)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (66.1.1)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.3.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.7/site-packages (from kubernetes<20,>=8.0.0->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (1.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging<22.0.0dev,>=14.3->google-cloud-aiplatform<2,>=1.14.0->google_cloud_pipeline_components) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (2.1.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from strip-hints<1,>=0.1.8->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (0.38.4)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema<5,>=3.0.1->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.31.5->google_cloud_pipeline_components) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib->kubernetes<20,>=8.0.0->kfp<2.0.0,>=1.8.9->google_cloud_pipeline_components) (3.2.2)
# Installing collected packages: grpcio-status, google-cloud-storage, google-cloud-notebooks, google-cloud-aiplatform, google_cloud_pipeline_components
#   Attempting uninstall: grpcio-status
#     Found existing installation: grpcio-status 1.48.2
#     Uninstalling grpcio-status-1.48.2:
#       Successfully uninstalled grpcio-status-1.48.2
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.44.0
#     Uninstalling google-cloud-storage-1.44.0:
#       Successfully uninstalled google-cloud-storage-1.44.0
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.3.0
#     Uninstalling google-cloud-aiplatform-1.3.0:
#       Successfully uninstalled google-cloud-aiplatform-1.3.0
# Successfully installed google-cloud-aiplatform-1.22.1 google-cloud-notebooks-1.6.1 google-cloud-storage-2.7.0 google_cloud_pipeline_components-1.0.39 grpcio-status-1.47.0

# %%
# Restart the kernel
import os

if not os.getenv("IS_TESTING"):
    # Automatically restart kernel after installs
    import IPython

    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

# %% [markdown]
# #### Set up the global variables

# %%
PATH=%env PATH
# %env PATH={PATH}:/home/jupyter/.local/bin
REGION="europe-west1"

# Get projet name
shell_output=!gcloud config get-value project 2> /dev/null
PROJECT_ID=shell_output[0]

# Set bucket name
BUCKET_NAME="gs://"+PROJECT_ID+"-bucket-winequality"

# Create bucket
PIPELINE_ROOT = f"{BUCKET_NAME}/pipeline_root_wine/"
PIPELINE_ROOT

USER_FLAG = "--user"
# Out:
# env: PATH=/opt/conda/bin:/opt/conda/condabin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/jupyter/.local/bin

# %% [markdown]
# ## Import Libraries
#  * Artifact,
#  * Dataset,
#  * Input,
#  * Model,
#  * Output,
#  * Metrics,
#  * ClassificationMetrics
#  * InputPath
#  * OutputPath

# %%
from typing import NamedTuple
import typing
from kfp.v2 import dsl
from kfp.v2.dsl import (Artifact,
                        Dataset,
                        Input,
                        Model,
                        Output,
                        Metrics,
                        ClassificationMetrics,
                        component, 
                        OutputPath, 
                        InputPath)

from kfp.v2 import compiler
from google.cloud import bigquery
from google.cloud import aiplatform
from google.cloud.aiplatform import pipeline_jobs
from google_cloud_pipeline_components import aiplatform as gcc_aip

# %% [markdown]
# ### Create pipeline
#
# We create 4 components:
# - Load data
# - Train a  model
# - Evaluate the model
# - Deploy the model
#
# The components have dependencies on `pandas`, `sklearn`.

# %%
# List columns
import pandas as pd
df_wine = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", delimiter=";")
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# Available columns:
# - volatile acidity :   Volatile acidity is the gaseous acids present in wine.
# - fixed acidity :   Primary fixed acids found in wine are tartaric, succinic, citric, and malic
# - residual sugar :   Amount of sugar left after fermentation.
# - citric acid :    It is weak organic acid, found in citrus fruits naturally.
# - chlorides :   Amount of salt present in wine.
# - free sulfur dioxide :   So2 is used for prevention of wine by oxidation and microbial spoilage.
# - total sulfur dioxide
# - pH :   In wine pH is used for checking acidity
# - density
# - sulphates :    Added sulfites preserve freshness and protect wine from oxidation, and bacteria.
# - alcohol :   Percent of alcohol present in wine.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %% [markdown]
# ### Read the wine quality dataset

# %%
#@component decorator in a Python script to define a Kubeflow 
@component(
    packages_to_install=["pandas", "pyarrow", "scikit-learn==1.0.2"],
    base_image="python:3.9",
    output_component_file="get_wine_data.yaml"
)

def get_wine_data(
    url: str,
    dataset_train: Output[Dataset],
    dataset_test: Output[Dataset]
):
    import pandas as pd
    import numpy as np
    from sklearn.model_selection import train_test_split as tts
    
    df_wine = pd.read_csv(url, delimiter=";")
    df_wine['best_quality'] = [ 1 if x>=7 else 0 for x in df_wine.quality] 
    df_wine['target'] = df_wine.best_quality
    df_wine = df_wine.drop(['quality', 'total sulfur dioxide', 'best_quality'], axis=1)
   
   
    train, test = tts(df_wine, test_size=0.3)
    train.to_csv(dataset_train.path + ".csv" , index=False, encoding='utf-8-sig')
    test.to_csv(dataset_test.path + ".csv" , index=False, encoding='utf-8-sig')

# %% [markdown]
# #### Train the wine quality model

# %%
@component(
    packages_to_install = [
        "pandas",
        "scikit-learn==1.0.2"
    ], base_image="europe-west1-docker.pkg.dev/vertex-ai-final/winequality/scikit-learn-winequality-train:latest",
)

def train_winequality(
    dataset:  Input[Dataset],
    model: Output[Model], 
):
    
    from sklearn.ensemble import RandomForestClassifier
    import pandas as pd
    import pickle

    data = pd.read_csv(dataset.path+".csv")
    model_rf = RandomForestClassifier(n_estimators=10)
    model_rf.fit(
        data.drop(columns=["target"]),
        data.target,
    )
    model.metadata["framework"] = "RF"
    file_name = model.path + f".pkl"
    with open(file_name, 'wb') as file:  
        pickle.dump(model_rf, file)

# %% [markdown]
# #### Evaluate the model

# %%
@component(
    packages_to_install = [
        "pandas",
        "scikit-learn==1.0.2"
    ], base_image="python:3.9",
)
def winequality_evaluation(
    test_set:  Input[Dataset],
    rf_winequality_model: Input[Model],
    thresholds_dict_str: str,
    metrics: Output[ClassificationMetrics],
    kpi: Output[Metrics]
) -> NamedTuple("output", [("deploy", str)]):

    from sklearn.ensemble import RandomForestClassifier
    import pandas as pd
    import logging 
    import pickle
    from sklearn.metrics import roc_curve, confusion_matrix, accuracy_score
    import json
    import typing

    
    def threshold_check(val1, val2):
        cond = "false"
        if val1 >= val2 :
            cond = "true"
        return cond

    data = pd.read_csv(test_set.path+".csv")
    model = RandomForestClassifier()
    file_name = rf_winequality_model.path + ".pkl"
    with open(file_name, 'rb') as file:  
        model = pickle.load(file)
    
    y_test = data.drop(columns=["target"])
    y_target=data.target
    y_pred = model.predict(y_test)
    

    y_scores =  model.predict_proba(data.drop(columns=["target"]))[:, 1]
    fpr, tpr, thresholds = roc_curve(
         y_true=data.target.to_numpy(), y_score=y_scores, pos_label=True
    )
    metrics.log_roc_curve(fpr.tolist(), tpr.tolist(), thresholds.tolist())  
    
    metrics.log_confusion_matrix(
       ["False", "True"],
       confusion_matrix(
           data.target, y_pred
       ).tolist(), 
    )
    
    accuracy = accuracy_score(data.target, y_pred.round())
    thresholds_dict = json.loads(thresholds_dict_str)
    rf_winequality_model.metadata["accuracy"] = float(accuracy)
    kpi.log_metric("accuracy", float(accuracy))
    deploy = threshold_check(float(accuracy), int(thresholds_dict['roc']))
    return (deploy,)

# %% [markdown]
# ### Deploy model

# %%
@component(
    packages_to_install=["google-cloud-aiplatform", "scikit-learn==1.0.2",  "kfp"],
    #base_image="europe-west1-docker.pkg.dev/PROJECT_ID/wine-train/scikit-learn-winequality:latest",
    base_image="python:3.9",
    output_component_file="model_winequality_coponent.yml"
)
def deploy_winequality(
    model: Input[Model],
    project: str,
    region: str,
    serving_container_image_uri : str, 
    vertex_endpoint: Output[Artifact],
    vertex_model: Output[Model]
):
    from google.cloud import aiplatform
    aiplatform.init(project=project, location=region)

    DISPLAY_NAME  = "winequality"
    MODEL_NAME = "winequality-rf"
    ENDPOINT_NAME = "winequality_endpoint"
    
    def create_endpoint():
        endpoints = aiplatform.Endpoint.list(
        filter='display_name="{}"'.format(ENDPOINT_NAME),
        order_by='create_time desc',
        project=project, 
        location=region,
        )
        if len(endpoints) > 0:
            endpoint = endpoints[0]  # most recently created
        else:
            endpoint = aiplatform.Endpoint.create(
            display_name=ENDPOINT_NAME, project=project, location=region
        )
    endpoint = create_endpoint()   
    
    
    #Import a model programmatically
    model_upload = aiplatform.Model.upload(
        display_name = DISPLAY_NAME, 
        artifact_uri = model.uri.replace("model", ""),
        serving_container_image_uri =  serving_container_image_uri,
        serving_container_health_route=f"/v1/models/{MODEL_NAME}",
        serving_container_predict_route=f"/v1/models/{MODEL_NAME}:predict",
        serving_container_environment_variables={
        "MODEL_NAME": MODEL_NAME,
    },       
    )
    model_deploy = model_upload.deploy(
        machine_type="n1-standard-4", 
        endpoint=endpoint,
        traffic_split={"0": 100},
        deployed_model_display_name=DISPLAY_NAME,
    )

    # Save data to the output params
    vertex_model.uri = model_deploy.resource_name

# %%
from datetime import datetime

TIMESTAMP =datetime.now().strftime("%Y%m%d%H%M%S")
DISPLAY_NAME = 'pipeline-winequality-job{}'.format(TIMESTAMP)

# %% [markdown]
# #### Create the Pipeline
#
# Once you have created all the needed components define the pipeline and then compile it into a `.json` file.

# %%
@dsl.pipeline(
    # Default pipeline root. You can override it when submitting the pipeline.
    pipeline_root=PIPELINE_ROOT,
    # A name for the pipeline. Use to determine the pipeline Context.
    name="pipeline-winequality",
    
)
def pipeline(
    url: str = "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv",
    project: str = PROJECT_ID,
    region: str = REGION, 
    display_name: str = DISPLAY_NAME,
    api_endpoint: str = REGION+"-aiplatform.googleapis.com",
    thresholds_dict_str: str = '{"roc":0.8}',
    serving_container_image_uri: str = "europe-docker.pkg.dev/vertex-ai/prediction/sklearn-cpu.0-24:latest"
    ):
    
    data_op = get_wine_data(url)
    train_model_op = train_winequality(data_op.outputs["dataset_train"])
    model_evaluation_op = winequality_evaluation(
        test_set=data_op.outputs["dataset_test"],
        rf_winequality_model=train_model_op.outputs["model"],
        thresholds_dict_str = thresholds_dict_str, # I deploy the model anly if the model performance is above the threshold
    )
    
    with dsl.Condition(
        model_evaluation_op.outputs["deploy"]=="true",
        name="deploy-winequality",
    ):
           
        deploy_model_op = deploy_winequality(
        model=train_model_op.outputs['model'],
        project=project,
        region=region, 
        serving_container_image_uri = serving_container_image_uri,
        )

# %% [markdown]
# ### Compile and run the pipeline

# %%
compiler.Compiler().compile(pipeline_func=pipeline,
        package_path='ml_winequality.json')
# Out:
# /home/jupyter/.local/lib/python3.7/site-packages/kfp/v2/compiler/compiler.py:1293: FutureWarning: APIs imported from the v1 namespace (e.g. kfp.dsl, kfp.components, etc) will not be supported by the v2 compiler since v2.0.0
#   category=FutureWarning,

# %% [markdown]
# The pipeline compilation generates the **ml_winequality.json** job spec file.

# %%
### Create a run

# %%
start_pipeline = pipeline_jobs.PipelineJob(
    display_name="winequality-pipeline",
    template_path="ml_winequality.json",
    enable_caching=False,
    location=REGION,
)

# %%
start_pipeline.run()
# Out:
# Creating PipelineJob
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      64         try:
# ---> 65             return callable_(*args, **kwargs)
#      66         except grpc.RpcError as exc:
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     945                                       wait_for_ready, compression)
# --> 946         return _end_unary_response_blocking(state, call, False, None)
#     947
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     848     else:
# --> 849         raise _InactiveRpcError(state)
#     850
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Invalid image URI europe-west1-docker.pkg.dev/7b64064241f27/winequality/scikit-learn-winequality-train:latest."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:74.125.197.95:443 {grpc_message:"Invalid image URI europe-west1-docker.pkg.dev/7b64064241f27/winequality/scikit-learn-winequality-train:latest.", grpc_status:3, created_time:"2023-03-04T04:05:20.591075751+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# /var/tmp/ipykernel_16771/1043187068.py in <module>
# ----> 1 start_pipeline.run()
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/aiplatform/pipeline_jobs.py in run(self, service_account, network, sync, create_request_timeout)
#     316             network=network,
#     317             sync=sync,
# --> 318             create_request_timeout=create_request_timeout,
#     319         )
#     320
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/aiplatform/base.py in wrapper(*args, **kwargs)
#     808                 if self:
#     809                     VertexAiResourceNounWithFutureManager.wait(self)
# --> 810                 return method(*args, **kwargs)
#     811
#     812             # callbacks to call within the Future (in same Thread)
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/aiplatform/pipeline_jobs.py in _run(self, service_account, network, sync, create_request_timeout)
#     346             service_account=service_account,
#     347             network=network,
# --> 348             create_request_timeout=create_request_timeout,
#     349         )
#     350
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/aiplatform/pipeline_jobs.py in submit(self, service_account, network, create_request_timeout, experiment)
#     421             pipeline_job=self._gca_resource,
#     422             pipeline_job_id=self.job_id,
# --> 423             timeout=create_request_timeout,
#     424         )
#     425
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/aiplatform_v1/services/pipeline_service/client.py in create_pipeline_job(self, request, parent, pipeline_job, pipeline_job_id, retry, timeout, metadata)
#    1349             retry=retry,
#    1350             timeout=timeout,
# -> 1351             metadata=metadata,
#    1352         )
#    1353
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     111             kwargs["metadata"] = metadata
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#     115
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      65             return callable_(*args, **kwargs)
#      66         except grpc.RpcError as exc:
# ---> 67             raise exceptions.from_grpc_error(exc) from exc
#      68
#      69     return error_remapped_callable
#
# InvalidArgument: 400 Invalid image URI europe-west1-docker.pkg.dev/7b64064241f27/winequality/scikit-learn-winequality-train:latest.

# %% [markdown]
# ### List all models

# %%
DISPLAY_NAME = "winequality"
! gcloud ai models list --region={REGION} --filter={DISPLAY_NAME}

# %% [markdown]
# ### Schedule pipeline

# %% [markdown]
# The scheduled jobs are supported by the Cloud Scheduler and Cloud Functions.
# Check that the APIs Cloud Scheduler, Cloud Functions are enabled.

# %% [markdown]
# ### Run recurrent pipeline

# %%
from kfp.v2.google.client import AIPlatformClient

api_client = AIPlatformClient(
                project_id=PROJECT_ID,
                region=REGION,
                )

SERVICE_ACCOUNT = (
    "196303161359-compute@developer.gserviceaccount.com" 
)
response = api_client.create_schedule_from_job_spec(
    enable_caching=True,
    job_spec_path="ml_winequality.json",
    schedule="0 0 * * 1", #once per week on Monday
    time_zone="Europe/Brussels",  # change this as necessary
    parameter_values={"display_name": DISPLAY_NAME},
    pipeline_root=PIPELINE_ROOT,  # this argument is necessary if you did not specify PIPELINE_ROOT as part of the pipeline definition.
    #service_account=SERVICE_ACCOUNT,
    
)

# %% [markdown]
# Once the scheduled job is created, you can see it listed in the Cloud Scheduler panel in the Console.

# %% [markdown]
# ### Test the batch prediction

# %%
## Optional Don't run
# Define variables 
job_display_name = "winequality-batch-prediction-job"
MODEL_NAME="winequality"
ENDPOINT_NAME="winequality_endpoint"
BUCKET_URI="gs://your-bucket-winequality/pipeline_root_wine/332188XXXX/pipeline-winequality-20211227155508/get-wine-data_8271177375014715392"
input_file_name="test.csv"

# Get model id
MODEL_ID=!(gcloud ai models list --region=$REGION \
           --filter=display_name=$MODEL_NAME)
MODEL_ID=MODEL_ID[2].split(" ")[0]

model_resource_name = f'projects/{PROJECT_ID}/locations/{REGION}/models/{MODEL_ID}'
gcs_source= [f"{BUCKET_URI}/{input_file_name}"]
gcs_destination_prefix=f"{BUCKET_URI}/output"

def batch_prediction_job(
    project: str,
    location: str,
    model_resource_name: str,
    job_display_name: str,
    gcs_source: str,
    gcs_destination_prefix: str,
    machine_type: str,
    starting_replica_count: int = 1, # The number of nodes for this batch prediction job. 
    max_replica_count: int = 1,    
):   
    aiplatform.init(project=project, location=location)

    model = aiplatform.Model(model_resource_name)

    batch_prediction_job = model.batch_predict(
        job_display_name=job_display_name,
        instances_format='csv', #json
        gcs_source=[f"{BUCKET_URI}/{input_file_name}"],
        gcs_destination_prefix=f"{BUCKET_URI}/output",
        machine_type=machine_type, # must be present      
    )
    batch_prediction_job.wait()
    print(batch_prediction_job.display_name)
    print(batch_prediction_job.state)
    return batch_prediction_job

batch_prediction_job(PROJECT_ID, REGION, model_resource_name, job_display_name, gcs_source, gcs_destination_prefix, machine_type="n1-standard-2")

# %% [markdown]
# ### Send an online prediction request
# Each prediction request must be max. 1.5 MB.

# %%
ENDPOINT_NAME="winequality_endpoint"
instance = [[7.2, 0.23, 0.32, 8.5, 0.058, 47, 132, 0.993, 3.12, 0.46]]
ENDPOINT_ID = !(gcloud ai endpoints list --region=$REGION \
              --format='value(ENDPOINT_ID)'\
              --filter=display_name=$ENDPOINT_NAME \
              --sort-by=creationTimeStamp | tail -1)
ENDPOINT_ID = ENDPOINT_ID[1]

def endpoint_predict(
    project: str, location: str, instances: list, endpoint: str
):
    aiplatform.init(project=project, location=location)

    endpoint = aiplatform.Endpoint(endpoint)

    prediction = endpoint.predict(instances=instances)
    return prediction

endpoint_predict(PROJECT_ID, REGION, instance, ENDPOINT_ID)
# Out:
# Prediction(predictions=[0.0], deployed_model_id='4181038100153106432', model_version_id='1', model_resource_name='projects/196303161359/locations/europe-west1/models/5699454862018740224', explanations=None)

# %% [markdown]
# ### Traina model using docker image

# %%
@component(
    packages_to_install = [
        "pandas",
        "scikit-learn==1.0.2"
    ], base_image="europe-west1-docker.pkg.dev/XXXXX/winequality/scikit-learn-winequality-train:latest",
)

def train_winequality(
    dataset:  Input[Dataset],
    model: Output[Model], 
):
    
    from sklearn.ensemble import RandomForestClassifier
    import pandas as pd
    import pickle

    data = pd.read_csv(dataset.path+".csv")
    model_rf = RandomForestClassifier(n_estimators=10)
    model_rf.fit(
        data.drop(columns=["target"]),
        data.target,
    )
    model.metadata["framework"] = "RF"
    file_name = model.path + f".pkl"
    with open(file_name, 'wb') as file:  
        pickle.dump(model_rf, file)
